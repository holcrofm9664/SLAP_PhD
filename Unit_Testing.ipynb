# %%
import unittest
from Models.Strict_S_Shape import Strict_S_Shape

# %%
loader = unittest.TestLoader()
suite = loader.discover('Unit_Tests')

runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)
# Out:
# test_instance_1 (test_strict_s_shape.Test_model.test_instance_1) ...
# Set parameter ServerPassword
# Set parameter TokenServer to value "10.42.67.199"
# ok
# test_instance_2 (test_strict_s_shape.Test_model.test_instance_2) ... ok
# test_instance_3 (test_strict_s_shape.Test_model.test_instance_3) ... ok
# test_instance_4 (test_strict_s_shape.Test_model.test_instance_4) ... ok
# test_output_type (test_strict_s_shape.Test_model.test_output_type) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.240s
#
# OK
# <unittest.runner.TextTestResult run=5 errors=0 failures=0>
